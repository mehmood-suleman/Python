# %% [markdown]
# How to read file

# %%
with open("profile.txt") as profile:
    contents=profile.read()
    print(contents)
# Out:
# My name is mehmood
# my father name is Suleman
# I am manager accounts at IIL,

# %%
print(contents.capitalize)
# Out:
# <built-in method capitalize of str object at 0x0000000008A095B0>

# %%
print(contents.rstrip())
# Out:
# My name is mehmood
# my father name is Suleman
# I am manager accounts at IIL,

# %%
print(contents.capitalize())
# Out:
# My name is mehmood
# my father name is suleman
# i am manager accounts at iil,

# %%
filepath='d:/python/profile.txt'
with open(filepath) as profile:
    contents=profile.read()
    print(contents)
# Out:
# my name is mehmood
# my father name is Suleman
# I am manager accounts at IIL.

# %%
with open(filepath,'a') as profile:
    profile.write(""+/n"Your name is Aslam")
# Out:
#   File "C:\Users\msuleman\AppData\Local\Temp/ipykernel_2044/1276830875.py", line 2
#     profile.write(""+/n"Your name is Aslam")
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# How to Read line from txt File

# %%
with open(filepath) as profile:
    for line in profile:
        print(line.rstrip())
# Out:
# my name is mehmood
# my father name is Suleman
# I am manager accounts at IIL.Your name is AslamYour name is AslamYour name is Aslam

# %% [markdown]
# How to read lines from txt files (2nd method)

# %%
with open(filepath) as profile:
    lines = profile.readlines()
for line in lines:
        print(line.rstrip())
# Out:
# my name is mehmood
# my father name is Suleman
# I am manager accounts at IIL.Your name is AslamYour name is AslamYour name is Aslam

# %%
name1 = "greeks"
name2 = "for"
name3 = "greeks"
print(name1.capitalize() + name2.capitalize()+ name3.capitalize())
# Out:
# GreeksForGreeks

# %%
name1 = "greeks"
name2 = "for"
name3 = "greeks"
print(name1.capitalize() +" " +name2.capitalize()+" "+name3.capitalize())
# Out:
# Greeks For Greeks

# %%
with open(filepath) as profile:
    lines = profile.readlines()
for line in lines:
        print(line.rstrip().capitalize())
# Out:
# My name is mehmood
# My father name is suleman
# I am manager accounts at iil.your name is aslamyour name is aslamyour name is aslam

# %%
with open("profile.txt") as profile:
    contents=profile.read()
    print(contents)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1444/626078988.py in <module>
# ----> 1 with open("profile.txt") as profile:
#       2     contents=profile.read()
#       3     print(contents)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'profile.txt'

# %%
example_list = []
for i in range (2):
    example_name = input("enter your name  ")
    example_list.append(example_name)
for i in example_list:
    print(i.capitalize)
# Out:
# enter your name  Mehmood
# enter your name  Aslam
# <built-in method capitalize of str object at 0x000000000A666F30>
# <built-in method capitalize of str object at 0x000000000A666470>

# %%
filepath='d:/python/profile.txt'
with open(filepath) as profile:
    contents=profile.read()
    print(contents)
# Out:
# my name is mehmood
# my father name is Suleman
# I am manager accounts at IIL.Your name is AslamYour name is AslamYour name is Aslam

# %%
import docx
filepath='d:/python/tmj.docx'
with open(filepath) as profile:
    contents=profile.read()
    print(contents)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17232/1855567717.py in <module>
# ----> 1 import docx
#       2 filepath='d:/python/tmj.docx'
#       3 with open(filepath) as profile:
#       4     contents=profile.read()
#       5     print(contents)
#
# ModuleNotFoundError: No module named 'docx'

# %%
import docx
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17232/964457360.py in <module>
# ----> 1 import docx
#
# ModuleNotFoundError: No module named 'docx'

# %%
from docx import document

# %%
pip install python-docx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import docx

# %%
import docx
filepath='d:/python/tmj.docx'
with open(filepath) as profile:
    contents=profile.read()
    print(contents)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17232/1855567717.py in <module>
#       2 filepath='d:/python/tmj.docx'
#       3 with open(filepath) as profile:
# ----> 4     contents=profile.read()
#       5     print(contents)
#
# ~\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 637: character maps to <undefined>

# %%
import docx
filepath='d:/python/tmj.docx'
with open(filepath) as profile:
    contents=profile.read()
    print(contents)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17232/1855567717.py in <module>
#       2 filepath='d:/python/tmj.docx'
#       3 with open(filepath) as profile:
# ----> 4     contents=profile.read()
#       5     print(contents)
#
# ~\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 637: character maps to <undefined>

# %%
filepath='d:/python/claim.docx'
with open(filepath) as profile:
    contents=profile.read()
    print(contents)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17232/262809763.py in <module>
#       1 filepath='d:/python/claim.docx'
#       2 with open(filepath) as profile:
# ----> 3     contents=profile.read()
#       4     print(contents)
#
# ~\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8f in position 591: character maps to <undefined>

# %%
import docx
filepath='d:/python/claim.docx'
doc = docx.Document(filepath)
len(doc.paragraphs)
# Out:
# 17

# %%
filepath='d:/python/claim.docx'
doc = docx.Document(filepath)
len(doc.paragraphs)
doc.paragraphs[1].runs[1].text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17232/3551169156.py in <module>
#       3 doc = docx.Document(filepath)
#       4 len(doc.paragraphs)
# ----> 5 doc.paragraphs[1].runs[0].text
#
# IndexError: list index out of range

# %%
filepath='d:/python/claim.docx'
doc = docx.Document(filepath)
len(doc.paragraphs)
doc.paragraphs[1].runs[0].text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17232/560474576.py in <module>
#       2 doc = docx.Document(filepath)
#       3 len(doc.paragraphs)
# ----> 4 doc.paragraphs[1].runs[0].text
#
# IndexError: list index out of range

# %%
filepath='d:/python/claim.docx'
doc = docx.Document(filepath)
len(doc.paragraphs)
a=doc.paragraphs.copy
print(a)
# Out:
# <built-in method copy of list object at 0x000000000B5CC0C0>

# %%
filepath='d:/python/claim.docx'
doc = docx.Document(filepath)
len(filepath)
# Out:
# 20

# %%
filepath='d:/python/claim.docx'
len(filepath)
# Out:
# 20

# %%
help docx()
# Out:
#   File "C:\Users\msuleman\AppData\Local\Temp/ipykernel_17232/1472975127.py", line 1
#     help docx()
#          ^
# SyntaxError: invalid syntax

# %%
filepath='d:/python/claim.docx'
doc = docx.Document(filepath)
len(doc.paragraphs)
# Out:
# 10

# %%
filepath='d:/python/claim.docx'
doc = docx.document(filepath)
len(doc.paragraphs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17232/3810932245.py in <module>
#       1 filepath='d:/python/claim.docx'
# ----> 2 doc = docx.document(filepath)
#       3 len(doc.paragraphs)
#
# TypeError: 'module' object is not callable

# %%
doc.paragraphs[1].text
# Out:
# 'It is hereby submitted that as on Sunday Nov 08, 2021, I was at Tariq Road'

# %%
for i in range(1,5):
    doc.paragraphs[i].text
    print(doc.paragraphs[i].text)
# Out:
# It is hereby submitted that as on Sunday Nov 08, 2021, I was at Tariq Road
# At 9:00 P.m.2 persons on bike come to me and snatched my mobile on gun point, honor 9X having IEMI no: 868012043615810.
# The necessary documents for insurance claim are submitted herewith.
# Bill

# %%
for i in range(1,5):
    print(doc.paragraphs[i].text)
# Out:
# It is hereby submitted that as on Sunday Nov 08, 2021, I was at Tariq Road
# At 9:00 P.m.2 persons on bike come to me and snatched my mobile on gun point, honor 9X having IEMI no: 868012043615810.
# The necessary documents for insurance claim are submitted herewith.
# Bill

# %%
for i in range(1,5):
        print(doc.paragraphs[i].text)
# Out:
#   File "C:\Users\msuleman\AppData\Local\Temp/ipykernel_17232/2524727383.py", line 2
#     print(doc.paragraphs[i].text & /n)
#                                    ^
# SyntaxError: invalid syntax

# %%
for i in range(0,11):
    print(doc.paragraphs[i].text)
# Out:
# To Whom it may Concern
# It is hereby submitted that as on Sunday Nov 08, 2021, I was at Tariq Road
# At 9:00 P.m.2 persons on bike come to me and snatched my mobile on gun point, honor 9X having IEMI no: 868012043615810.
# The necessary documents for insurance claim are submitted herewith.
# Bill
# FIR Copy
# Box
# CNIC copy
# Regards
# Mehmood Suleman
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17232/3784077707.py in <module>
#       1 for i in range(0,11):
# ----> 2     print(doc.paragraphs[i].text)
#       3
#
# IndexError: list index out of range

# %%
for i in range(0,10):
    print(doc.paragraphs[i].text)
# Out:
# To Whom it may Concern
# It is hereby submitted that as on Sunday Nov 08, 2021, I was at Tariq Road
# At 9:00 P.m.2 persons on bike come to me and snatched my mobile on gun point, honor 9X having IEMI no: 868012043615810.
# The necessary documents for insurance claim are submitted herewith.
# Bill
# FIR Copy
# Box
# CNIC copy
# Regards
# Mehmood Suleman

# %%
doc.paragraphs[1].runs[0]

# %%
doc.paragraphs[1].runs[0].text
# Out:
# 'It is hereby submitted '

# %%
doc.paragraphs[1].runs[1].text
# Out:
# 'that as on '

# %%
doc.paragraphs[1].runs[2].text
# Out:
# 'Sunday '

# %%
doc.paragraphs[1].runs[3].text
# Out:
# 'Nov'

# %%
doc.paragraphs[1].runs[4].text
# Out:
# ' '

# %%
for i in range(0,5):
    print(doc.paragraphs[1].runs[i].text
# Out:
#   File "C:\Users\msuleman\AppData\Local\Temp/ipykernel_17232/19626504.py", line 2
#     print(doc.paragraphs[1].runs[i].text
#                                         ^
# SyntaxError: unexpected EOF while parsing

# %%
filepath='d:/python/TMJ.docx'
len(filepath)
# Out:
# 18

# %%
for i in range(0,18):
    print(doc.paragraphs[i].text)
# Out:
# To Whom it may Concern
# It is hereby submitted that as on Sunday Nov 08, 2021, I was at Tariq Road
# At 9:00 P.m.2 persons on bike come to me and snatched my mobile on gun point, honor 9X having IEMI no: 868012043615810.
# The necessary documents for insurance claim are submitted herewith.
# Bill
# FIR Copy
# Box
# CNIC copy
# Regards
# Mehmood Suleman
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17232/3564147817.py in <module>
#       1 for i in range(0,18):
# ----> 2     print(doc.paragraphs[i].text)
#
# IndexError: list index out of range

# %%
filepath='d:/python/TMJ.docx'
doc = docx.Document(filepath)
len(doc.paragraphs)
# Out:
# 5

# %%
doc.
for i in range(0,5):
    print(doc.paragraphs[1].runs[i].text
# Out:
#   File "C:\Users\msuleman\AppData\Local\Temp/ipykernel_17232/19626504.py", line 2
#     print(doc.paragraphs[1].runs[i].text
#                                         ^
# SyntaxError: unexpected EOF while parsing

# %%
filepath='d:/python/TMJ.docx'
doctmj = docx.Document(filepath)
len(doc.paragraphs)
# Out:
# 5

# %%
doctmj.paragraphs.count(a)
# Out:
# 0

# %%
filepathtmj='d:/python/TMJ.docx'
doctmj = docx.Document(filepathtmj)
len(doctmj.paragraphs)
# Out:
# 5

# %%
filepathclaim='d:/python/claim.docx'
docclaim = docx.Document(filepathclaim)
len(docclaim.paragraphs)
# Out:
# 10

# %%
docclaim.paragraphs[1].text
# Out:
# 'بلیٹ پیپر برائے الیکشن 22-2021 اور 23-2022'

# %%
doctmj.paragraphs[1].text
# Out:
# 'بلیٹ پیپر برائے الیکشن 22-2021 اور 23-2022'

# %%
doctmj.paragraphs[0].text
# Out:
# 'TARSAI MEMON JAMAT'

# %%
doctmj.paragraphs[2].text
# Out:
# 'اُمید وار برائے جوائنٹ سیکریٹری (کسی ایک پر نشان لگائیں)'

# %%
doctmj.paragraphs[3].text
# Out:
# 'اُمید وار برائے ممبر منیجنگ کمیٹی (کسی  چھ پر نشان لگائیں)'

# %%
doctmj.paragraphs[4].text
# Out:
# ''

# %%
doctmj.paragraphs[5].text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17232/4206064167.py in <module>
# ----> 1 doctmj.paragraphs[5].text
#
# IndexError: list index out of range

# %%
doctmj.tables[1].cell
# Out:
# <bound method Table.cell of <docx.table.Table object at 0x000000000B5317C0>>

# %%
doctmj.tables[0].cell[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17232/2935619112.py in <module>
# ----> 1 doctmj.tables[0].cell[1]
#
# TypeError: 'method' object is not subscriptable
